# %% [markdown]
# # DrugOOD Demo
#
# Welcome to DrugOOD! This is the official tutorial for using from drugood. In this tutorial, you will get the following:
#
# - Curate a new OOD dataset from the ChEMBL database.
# - Train an OOD algorithm with the generated dataset.
#
# Let's get started!

# %% [markdown]
# ## Enviorment Preparing
#
# ### Conda Env Installation
#
# Firstly, make sure that you have installed the env following the readme.md.

# %% [markdown]
# ### DrugOOD Installation

# %% [markdown]
# Then you can install the drugood package. Make sure that you are in the code root folder:

# %%
# %cd ../
# %pwd

# %%
# !python setup.py  install

# %% [markdown]
# ## DrugOOD Dataset Curator
#
# DrugOOD benchmark has provided 96 bulit-in datasets. You can coustom your own ood dataset by using the dataset curator. The dataset curator currently focuses on generating datasets from the deposition website CHEMBL.
#
# It supports the following two tasks:
# - Ligand Based Affinity Prediction (LBAP for short).
# - Stucture Based Affinity Prediction (SBAP for short).
#
# For domains, it supports the following 5 choices.
#
# - Assay.
# - Scaffold.
# - Size.
# - Protein. (only for SBAP task)
# - Protein Family. (only for SBAP task)
#
# For noise annotations, it supports the following three noise levels, together with a full set. Datasets with different noises are implemented by filters with different levels of strictness.
#
# - Core.
# - Refined.
# - General.
#
# At the same time, due to the inconvenient conversion between different measurement type (E.g. IC50, EC50, Ki, Potency), user can specify the targeted measurement type when generating the dataset.
#
# ### Chembl Database Download
# To custom a new dataset using DrugOOD dataset curator, let's first download the chembl29 database in the sqllite format.  Assume that you put it in you local folder: `CHEMBL_SQLLITE/`

# %%
# !wget http://ftp.ebi.ac.uk/pub/databases/chembl/ChEMBLdb/releases/chembl_29/chembl_29_sqlite.tar.gz
# !tar -xvf chembl_29_sqlite.tar.gz > CHEMBL_SQLLITE/
# Out:
# --2022-02-08 14:33:37--  http://ftp.ebi.ac.uk/pub/databases/chembl/ChEMBLdb/releases/chembl_29/chembl_29_sqlite.tar.gz
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.138|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4218778217 (3.9G) [application/octet-stream]
# Saving to: 'chembl_29_sqlite.tar.gz'
#
#  0% [                                       ] 14,605,509   112KB/s  eta 20h 34m

# %%
# Check the directory structure of the downloaded 
# Install tree first
# !apt-get -q install tree
# !tree CHEMBL_SQLLITE/chembl_29_sqlite

# %% [markdown]
# ### Modify the curation config
# In the next step, we need to modify the config file for the data curator. To accelerate the process, we modify the configuration based on a built-in dataset's config.

# %%
# %cd demo

# %%
from mmcv import Config
cfg = Config.fromfile('../configs/curators/lbap_core_ec50_assay.py')

# %%
print(f'Built-in Config:\n{cfg.pretty_text}')
# Out:
# Built-in Config:
# path = dict(
#     task=dict(type='lbap', subset='lbap_core_ec50_assay'),
#     source_root=
#     '/apdcephfs/share_1364275/xluzhang/chembl_29_sqlite/chembl_29.db',
#     target_root='data/')
# uncertainty = dict(delta=dict({'<': -1, '<=': -1, '>': 1, '>=': 1}))
# classification_threshold = dict(lower_bound=4, upper_bound=6, fix_value=5)
# fractions = dict(
#     train_fraction_ood=0.6,
#     val_fraction_ood=0.2,
#     iid_train_sample_fractions=0.6,
#     iid_val_sample_fractions=0.2)
# noise_filter = dict(
#     assay=dict(
#         measurement_type=['EC50'],
#         assay_value_units=['nM', 'uM'],
#         molecules_number=[50, 3000],
#         confidence_score=9),
#     sample=dict(
#         filter_none=[],
#         smile_exist=[],
#         smile_legal=[],
#         value_relation=['=', '~']))
# domain = dict(
#     domain_generate_field='assay_id',
#     domain_name='assay',
#     sort_func='domain_capacity',
#     sort_order='descend',
#     protein_family_level=1)

# %% [markdown]
# We modify some values to customize the dataset we need. For example, we want to filter out data with molecule numbers outside of [50, 100].

# %%
cfg.noise_filter.assay.molecules_number=[50, 100]
cfg.path.task.subset ="lbap_core_ec50_assay_custom"
print(f'Built-in Config:\n{cfg.pretty_text}')
# Out:
# Built-in Config:
# path = dict(
#     task=dict(type='lbap', subset='lbap_core_ec50_assay_custom'),
#     source_root=
#     '/apdcephfs/share_1364275/xluzhang/chembl_29_sqlite/chembl_29.db',
#     target_root='data/')
# uncertainty = dict(delta=dict({'<': -1, '<=': -1, '>': 1, '>=': 1}))
# classification_threshold = dict(lower_bound=4, upper_bound=6, fix_value=5)
# fractions = dict(
#     train_fraction_ood=0.6,
#     val_fraction_ood=0.2,
#     iid_train_sample_fractions=0.6,
#     iid_val_sample_fractions=0.2)
# noise_filter = dict(
#     assay=dict(
#         measurement_type=['EC50'],
#         assay_value_units=['nM', 'uM'],
#         molecules_number=[50, 100],
#         confidence_score=9),
#     sample=dict(
#         filter_none=[],
#         smile_exist=[],
#         smile_legal=[],
#         value_relation=['=', '~']))
# domain = dict(
#     domain_generate_field='assay_id',
#     domain_name='assay',
#     sort_func='domain_capacity',
#     sort_order='descend',
#     protein_family_level=1)

# %% [markdown]
# ### Generating new ood dataset
#
# Now, lets's generate the new ood dataset. It may take some time the first time running, cause
# it will cache the processed SQL data the first time. The second time running it will automacally load
# the cached data.

# %%
from drugood.apis.curate import curate_data

curate_data(cfg)
# Out:
# Using backend: pytorch
# Curator Config:
# path = dict(
#     task=dict(type='lbap', subset='lbap_core_ec50_assay_custom'),
#     source_root=
#     '/apdcephfs/share_1364275/xluzhang/chembl_29_sqlite/chembl_29.db',
#     target_root='data/')
# uncertainty = dict(delta=dict({'<': -1, '<=': -1, '>': 1, '>=': 1}))
# classification_threshold = dict(lower_bound=4, upper_bound=6, fix_value=5)
# fractions = dict(
#     train_fraction_ood=0.6,
#     val_fraction_ood=0.2,
#     iid_train_sample_fractions=0.6,
#     iid_val_sample_fractions=0.2)
# noise_filter = dict(
#     assay=dict(
#         measurement_type=['EC50'],
#         assay_value_units=['nM', 'uM'],
#         molecules_number=[50, 100],
#         confidence_score=9),
#     sample=dict(
#         filter_none=[],
#         smile_exist=[],
#         smile_legal=[],
#         value_relation=['=', '~']))
# domain = dict(
#     domain_generate_field='assay_id',
#     domain_name='assay',
#     sort_func='domain_capacity',
#     sort_order='descend',
#     protein_family_level=1)
#
# ------------------------------------------------------------
# Data Loading: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 18635916/18635916 [00:21<00:00, 870789.53it/s]
# Noise Filtering: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 1383351/1383351 [01:31<00:00, 15101.44it/s]
# Uncertainty Processing: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 8255/8255 [00:00<00:00, 2500829.15it/s]
# data saved to data/lbap_core_ec50_assay_custom.json
# ------------------------------------------------------------
# +-------------------------------------------+
# |     Statistics of curated ood dataset     |
# +----------+---------------+----------------+
# |  split   | domain number | sample number  |
# +----------+---------------+----------------+
# |  train   |       55      |      2039      |
# | iid_val  |       55      |      665       |
# | ood_val  |       26      |      1130      |
# | iid_test |       55      |      730       |
# | ood_test |       60      |      1113      |
# +----------+---------------+----------------+

# %% [markdown]
# The curated dataset will be stored in the `target_root` dir, which is "data" here. let's check the directory structure of the result.

# %%
# !tree data/
# Out:
# data/
# `-- lbap_core_ec50_assay_custom.json
#
# 0 directories, 1 file

# %% [markdown]
# Let's visulize some example from this new dataset

# %%
import mmcv
data = mmcv.load("data/lbap_core_ec50_assay_custom.json")
train = data["split"]["train"]
ood_test = data["split"]["ood_test"]

# %%
ood_test
# Out:
# [{'smiles': 'COCCNCCC(=O)N[C@H]1c2ccccc2C[C@@H]1NC(=O)c1cc2ccccc2n1C',
#   'reg_label': 6.8,
#   'assay_id': 1722251,
#   'cls_label': 1,
#   'domain_id': 119},
#  {'smiles': 'CN(C)CCC(=O)N[C@H]1c2ccccc2C[C@@H]1NC(=O)c1cc2cc(F)c(F)cc2[nH]1',
#   'reg_label': 7.48,
#   'assay_id': 1722251,
#   'cls_label': 1,
#   'domain_id': 119},
#  {'smiles': 'O=C(N[C@H]1Cc2ccccc2[C@@H]1NC(=O)[C@H]1CCNC1)c1cc2cc(F)ccc2[nH]1',
#   'reg_label': 7.3149999999999995,
#   'assay_id': 1722251,
#   'cls_label': 1,
#   'domain_id': 119},
#  {'smiles': 'Cc1ccc2[nH]c(C(=O)N[C@H]3Cc4ccccc4[C@@H]3NC(=O)CCN(C)C)cc2c1',
#   'reg_label': 7.6899999999999995,
#   'assay_id': 1722251,
#   'cls_label': 1,
#   'domain_id': 119},
#  {'smiles': 'Cc1ccc2[nH]c(C(=O)N[C@@H]3Cc4ccccc4[C@H]3NC(=O)CCN(C)C)cc2c1',
#   'reg_label': 6.625,
#   'assay_id': 1722251,
#   'cls_label': 1,
#   'domain_id': 119},
#  {'smiles': 'Cc1ccc2[nH]c(C(=O)N[C@H]3Cc4ccccc4[C@H]3NC(=O)CCN(C)C)cc2c1',
#   'reg_label': 7.0,
#   'assay_id': 1722251,
#   'cls_label': 1,
#   'domain_id': 119},
#  {'smiles': 'Cc1ccc2[nH]c(C(=O)N[C@@H]3Cc4ccccc4[C@@H]3NC(=O)CCN(C)C)cc2c1',
#   'reg_label': 5.8100000000000005,
#   'assay_id': 1722251,
#   'cls_label': 1,
#   'domain_id': 119},
#  {'smiles': 'CN1N=C2CCN(C(=O)[C@@H](COCc3ccccc3)NC(=O)C(C)(C)N)C[C@@]2(Cc2ccccc2)C1=O',
#   'reg_label': 9.045,
#   'assay_id': 1722251,
#   'cls_label': 1,
#   'domain_id': 119},
#  {'smiles': 'Cn1c(C(=O)N[C@H]2Cc3ccccc3[C@@H]2NC(=O)c2cnccc2N)cc2ccccc21',
#   'reg_label': 7.8100000000000005,
#   'assay_id': 1722251,
#   'cls_label': 1,
#   'domain_id': 119},
#  {'smiles': 'Nc1ccncc1C(=O)N[C@H]1c2ccccc2C[C@@H]1NC(=O)c1nc2cc(F)c(F)cc2[nH]1',
#   'reg_label': 7.619999999999999,
#   'assay_id': 1722251,
#   'cls_label': 1,
#   'domain_id': 119},
#  {'smiles': 'Nc1ccncc1C(=O)N[C@H]1c2ccccc2C[C@@H]1NC(=O)c1cc2c(F)cc(F)cc2[nH]1',
#   'reg_label': 8.559999999999999,
#   'assay_id': 1722251,
#   'cls_label': 1,
#   'domain_id': 119},
#  {'smiles': 'Cn1ccc2c(F)c(C(=O)N[C@H]3Cc4ccccc4[C@@H]3NC(=O)c3cnccc3N)ccc21',
#   'reg_label': 8.26,
#   'assay_id': 1722251,
#   'cls_label': 1,
#   'domain_id': 119},
#  {'smiles': 

#   'assay_id': 357594,
#   'cls_label': 1,
#   'domain_id': 8},
#  {'smiles': 'CC(C)(N)C(=O)N[C@H](Cc1c[nH]c2ccccc12)C(=O)N1CCC2(CC1)CS(=O)(=O)c1ccccc12',
#   'reg_label': 8.68,
#   'assay_id': 357594,
#   'cls_label': 1,
#   'domain_id': 8},
#  {'smiles': 'CC(C)(N)C(=O)N[C@H](Cc1c[nH]c2ccccc12)C(=O)N1CCC2(CC1)CSc1ccccc12',
#   'reg_label': 8.25,
#   'assay_id': 357594,
#   'cls_label': 1,
#   'domain_id': 8},
#  {'smiles': 'CC(C)(N)C(=O)N[C@H](Cc1c[nH]c2ccccc12)C(=O)N1CCC2(CCc3ccccc32)CC1',
#   'reg_label': 7.85,
#   'assay_id': 357594,
#   'cls_label': 1,
#   'domain_id': 8},
#  {'smiles': 'CC(C)Sc1cc(-c2ccc(CCNC[C@H](O)c3cnccc3N)cc2)ccc1C(=O)NS(C)(=O)=O',
#   'reg_label': 10.1,
#   'assay_id': 497791,
#   'cls_label': 1,
#   'domain_id': 22},
#  {'smiles': 'CS(=O)(=O)NC(=O)c1ccc(-c2ccc(CCNC[C@H](O)c3cnccc3N)cc2)cc1OC1CCCCC1.Cl.Cl',
#   'reg_label': 10.52,
#   'assay_id': 497791,
#   'cls_label': 1,
#   'domain_id': 22},
#  {'smiles': 'CC(C)Oc1cc(-c2ccc(CCNC[C@H](O)c3cnccc3N)cc2)ccc1C(=O)NS(C)(=O)=O',
#   'reg_label': 9.875,
#   'assay_id': 497791,
#   'cls_label': 1,
#   'domain_id': 22},
#  {'smiles': 'CCOc1cc(-c2ccc(CCNC[C@H](O)c3cnccc3N)cc2)ccc1C(=O)NS(C)(=O)=O',
#   'reg_label': 9.17,
#   'assay_id': 497791,
#   'cls_label': 1,
#   'domain_id': 22},
#  {'smiles': 'CS(=O)(=O)NC(=O)c1ccc(-c2ccc(CCNC[C@H](O)c3ccc(N)cc3)cc2)cc1OC1CCCCC1.Cl.Cl',
#   'reg_label': 9.75,
#   'assay_id': 497791,
#   'cls_label': 1,
#   'domain_id': 22},
#  {'smiles': 'CC(C)Oc1cc(-c2ccc(CCNC[C@H](O)c3ccc(N)cc3)cc2)ccc1C(=O)NS(C)(=O)=O.Cl.Cl',
#   'reg_label': 8.98,
#   'assay_id': 497791,
#   'cls_label': 1,
#   'domain_id': 22},
#  {'smiles': 'CC(C)Sc1cc(-c2ccc(CCNC[C@H](O)c3cccnc3)cc2)ccc1C(=O)NS(C)(=O)=O.Cl.Cl',
#   'reg_label': 9.72,
#   'assay_id': 497791,
#   'cls_label': 1,
#   'domain_id': 22},
#  {'smiles': 'CS(=O)(=O)NC(=O)c1ccc(-c2ccc(CCNC[C@H](O)c3cccnc3)cc2)cc1C1CCCC1.Cl.Cl',
#   'reg_label': 9.54,
#   'assay_id': 497791,
#   'cls_label': 1,
#   'domain_id': 22},
#  {'smiles': 'CC(C)Cc1cc(-c2ccc(CCNC[C@H](O)c3cccnc3)cc2)ccc1C(=O)NS(C)(=O)=O.Cl.Cl',
#   'reg_label': 9.49,
#   'assay_id': 497791,
#   'cls_label': 1,
#   'domain_id': 22},
#  {'smiles': 'CS(=O)(=O)NC(=O)c1ccc(-c2ccc(CCNC[C@H](O)c3cccnc3)cc2)cc1NC1CCCCC1.Cl.Cl.Cl',
#   'reg_label': 10.21,
#   'assay_id': 497791,
#   'cls_label': 1,
#   'domain_id': 22},
#  {'smiles': 'CC(C)Nc1cc(-c2ccc(CCNC[C@H](O)c3cccnc3)cc2)ccc1C(=O)NS(C)(=O)=O.Cl.Cl.Cl',
#   'reg_label': 9.7,
#   'assay_id': 497791,
#   'cls_label': 1,
#   'domain_id': 22},
#  {'smiles': 'CS(=O)(=O)NC(=O)c1ccc(-c2ccc(CCNC[C@H](O)c3cccnc3)cc2)cc1OC1CCCCC1.Cl.Cl',
#   'reg_label': 9.89,
#   'assay_id': 497791,
#   'cls_label': 1,
#   'domain_id': 22},
#  {'smiles': 'CC(C)Oc1cc(-c2ccc(CCNC[C@H](O)c3cccnc3)cc2)ccc1C(=O)NS(C)(=O)=O.Cl.Cl',
#   'reg_label': 9,
#   'assay_id': 497791,
#   'cls_label': 1,
#   'domain_id': 22},
#  {'smiles': 'CS(=O)(=O)NC(=O)c1ccc(-c2ccc(CCNC[C@H](O)c3ccccc3)cc2)cc1SC1CCCCC1.Cl',
#   'reg_label': 9.3,
#   'assay_id': 497791,
#   'cls_label': 1,
#   'domain_id': 22},
#  {'smiles': 

#   'assay_id': 497791,
#   'cls_label': 1,
#   'domain_id': 22},
#  {'smiles': 'CC(C)Cc1cc(-c2ccc(CCNC[C@H](O)c3cnccc3N)cc2)ccc1C(=O)O',
#   'reg_label': 10.18,
#   'assay_id': 497791,
#   'cls_label': 1,
#   'domain_id': 22},
#  {'smiles': 'Nc1ccncc1[C@@H](O)CNCCc1ccc(-c2ccc(C(=O)O)c(OC3CCCCC3)c2)cc1',
#   'reg_label': 10.46,
#   'assay_id': 497791,
#   'cls_label': 1,
#   'domain_id': 22},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#Cc2ccccn2)cn1)C(C)(C)C',
#   'reg_label': 5.21,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#Cc2ncccc2F)cn1)C(C)(C)O',
#   'reg_label': 5.43,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#Cc2cc(F)ccn2)cn1)C(C)(C)O',
#   'reg_label': 5.4,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#Cc2ccc(F)cn2)cn1)C(C)(C)O',
#   'reg_label': 5.77,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#Cc2cccc(F)n2)cn1)C(C)(C)O',
#   'reg_label': 5.89,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'CC1(CCNC(=O)c2ccc(C#Cc3cccc(F)c3)cn2)COC1',
#   'reg_label': 5.55,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@H](NC(=O)c1ccc(C#Cc2cccc(F)c2)cn1)C(F)(F)F',
#   'reg_label': 5.86,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'O=C(NCC(F)(F)F)c1ccc(C#Cc2cccc(F)c2)cn1',
#   'reg_label': 4.97,
#   'assay_id': 984563,
#   'cls_label': 0,
#   'domain_id': 73},
#  {'smiles': 'CC(C)(O)CNC(=O)c1ccc(C#Cc2cccc(F)c2)cn1',
#   'reg_label': 5.4,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'CC(C)(CO)NC(=O)c1ccc(C#Cc2cccc(F)c2)cn1',
#   'reg_label': 6.14,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'CC(C)(C)CNC(=O)c1ccc(C#Cc2cccc(F)c2)cn1',
#   'reg_label': 5.59,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'CCCNC(=O)c1ccc(C#Cc2cccc(F)c2)cn1',
#   'reg_label': 5.52,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#Cc2cccc(F)c2)cn1)C(C)(C)F',
#   'reg_label': 5.6850000000000005,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'CC(C)[C@H](C)NC(=O)c1ccc(C#Cc2cccc(F)c2)cn1',
#   'reg_label': 5.65,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'CC(C)[C@@H](C)NC(=O)c1ccc(C#Cc2cccc(F)c2)cn1',
#   'reg_label': 5.83,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@H](NC(=O)c1ccc(C#Cc2cccc(F)c2)cn1)C(C)(C)C',
#   'reg_label': 5.27,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#Cc2cccc(F)c2)cn1)C(C)(C)C',
#   'reg_label': 5.56,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1nc(C#Cc2cccc(F)c2)cs1)C(C)(C)O',
#   'reg_label': 5.32,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1cnc(C#Cc2cccc(F)c2)cn1)C(C)(C)O',
#   'reg_label': 5.52,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#Cc2cccc(F)c2)nn1)C(C)(C)O',
#   'reg_label': 5.67,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ncc(C#Cc2cccc(F)c2)cn1)C(C)(C)O',
#   'reg_label': 5.38,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'Cc1nc(C#Cc2cccc(F)c2)ccc1C(=O)N[C@H](C)C(C)(C)O',
#   'reg_label': 5.96,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#Cc2cccc(F)c2)nc1)C(C)(C)O',
#   'reg_label': 5.17,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#Cc2cccc(F)c2)cc1)C(C)(C)O',
#   'reg_label': 5.98,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#CC2CCCC2)cn1)C(C)(C)O',
#   'reg_label': 5.01,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#Cc2ccncc2)cn1)C(C)(C)O',
#   'reg_label': 5.33,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#Cc2cccnc2)cn1)C(C)(C)O',
#   'reg_label': 5.03,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'Cc1cccc(C#Cc2ccc(C(=O)N[C@H](C)C(C)(C)O)nc2)c1',
#   'reg_label': 5.87,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'Cc1ccccc1C#Cc1ccc(C(=O)N[C@H](C)C(C)(C)O)nc1',
#   'reg_label': 4.91,
#   'assay_id': 984563,
#   'cls_label': 0,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#Cc2ccc(F)cc2F)cn1)C(C)(C)O',
#   'reg_label': 5.43,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#Cc2cc(F)cc(F)c2)cn1)C(C)(C)O',
#   'reg_label': 5.4350000000000005,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#Cc2ccc(F)cc2)cn1)C(C)(C)O',
#   'reg_label': 5.82,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#Cc2cccc(F)c2)cn1)C(C)(C)O',
#   'reg_label': 6.04,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#Cc2ccccc2F)cn1)C(C)(C)O',
#   'reg_label': 5.94,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'C[C@@H](NC(=O)c1ccc(C#Cc2ccccc2)cn1)C(C)(C)O',
#   'reg_label': 6.06,
#   'assay_id': 984563,
#   'cls_label': 1,
#   'domain_id': 73},
#  {'smiles': 'Cc1ccoc1C(=O)Nc1ccc(N2C(=O)c3ccc(Cl)cc3C2=O)cc1F',
#   'reg_label': 6.775,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1ccoc1C(=O)Nc1ccc(N2C(=O)c3cccc(C)c3C2=O)cc1F',
#   'reg_label': 6.09,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1ccc2c(c1)C(=O)N(c1ccc(NC(=O)c3occc3C)c(F)c1)C2=O',
#   'reg_label': 6.823333333333333,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1cn[nH]c1C(=O)Nc1ccc(N2C(=O)c3ccc(F)cc3C2=O)c(Cl)c1',
#   'reg_label': 6.2,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1cn[nH]c1C(=O)Nc1ccc(N2C(=O)c3ccc(Cl)cc3C2=O)c(Cl)c1',
#   'reg_label': 6.07,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1cn[nH]c1C(=O)Nc1ccc(N2C(=O)c3cccc(C)c3C2=O)c(Cl)c1',
#   'reg_label': 5.335,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1ccc2c(c1)C(=O)N(c1ccc(NC(=O)c3[nH]ncc3C)cc1Cl)C2=O',
#   'reg_label': 6.25,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cn1ccnc1C(=O)Nc1ccc(N2C(=O)c3ccc(F)cc3C2=O)c(Cl)c1',
#   'reg_label': 6.17,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cn1ccnc1C(=O)Nc1ccc(N2C(=O)c3ccc(Cl)cc3C2=O)c(Cl)c1',
#   'reg_label': 6.58,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1ccc2c(c1)C(=O)N(c1ccc(NC(=O)c3nccn3C)cc1Cl)C2=O',
#   'reg_label': 6.595,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1scnc1C(=O)Nc1ccc(N2C(=O)c3cccnc3C2=O)c(Cl)c1',
#   'reg_label': 6.72,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1scnc1C(=O)Nc1ccc(N2C(=O)c3cccc(F)c3C2=O)c(Cl)c1',
#   'reg_label': 6.73,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1scnc1C(=O)Nc1ccc(N2C(=O)c3ccc(F)cc3C2=O)c(Cl)c1',
#   'reg_label': 7.2,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1scnc1C(=O)Nc1ccc(N2C(=O)c3cccc(Cl)c3C2=O)c(Cl)c1',
#   'reg_label': 5.86,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1scnc1C(=O)Nc1ccc(N2C(=O)c3ccc(Cl)cc3C2=O)c(Cl)c1',
#   'reg_label': 7.295,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1cccc2c1C(=O)N(c1ccc(NC(=O)c3ncsc3C)cc1Cl)C2=O',
#   'reg_label': 6.635,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1ccc2c(c1)C(=O)N(c1ccc(NC(=O)c3ncsc3C)cc1Cl)C2=O',
#   'reg_label': 7.66,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1ocnc1C(=O)Nc1ccc(N2C(=O)c3cccnc3C2=O)c(Cl)c1',
#   'reg_label': 5.77,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1ocnc1C(=O)Nc1ccc(N2C(=O)c3cccc(F)c3C2=O)c(Cl)c1',
#   'reg_label': 6.195,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1ocnc1C(=O)Nc1ccc(N2C(=O)c3ccc(F)cc3C2=O)c(Cl)c1',
#   'reg_label': 6.85,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1ocnc1C(=O)Nc1ccc(N2C(=O)c3cccc(Cl)c3C2=O)c(Cl)c1',
#   'reg_label': 5.885,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1ocnc1C(=O)Nc1ccc(N2C(=O)c3ccc(Cl)cc3C2=O)c(Cl)c1',
#   'reg_label': 7.265,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1cccc2c1C(=O)N(c1ccc(NC(=O)c3ncoc3C)cc1Cl)C2=O',
#   'reg_label': 6.325,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1cn[nH]c1C(=O)Nc1ccc(N2C(=O)c3cccc(F)c3C2=O)c(Cl)c1',
#   'reg_label': 6.9350000000000005,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1ccc2c(c1)C(=O)N(c1ccc(NC(=O)c3ncoc3C)cc1Cl)C2=O',
#   'reg_label': 7.385,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1cn[nH]c1C(=O)Nc1ccc(N2C(=O)c3ccccc3C2=O)c(Cl)c1',
#   'reg_label': 5.91,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cn1ccnc1C(=O)Nc1ccc(N2C(=O)c3ccccc3C2=O)c(Cl)c1',
#   'reg_label': 6.4399999999999995,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1scnc1C(=O)Nc1ccc(N2C(=O)c3ccccc3C2=O)c(Cl)c1',
#   'reg_label': 7.24,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1ocnc1C(=O)Nc1ccc(N2C(=O)c3ccccc3C2=O)c(Cl)c1',
#   'reg_label': 5.83,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1sccc1C(=O)Nc1ccc(N2C(=O)c3ccccc3C2=O)c(Cl)c1',
#   'reg_label': 5.82,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1ccsc1C(=O)Nc1ccc(N2C(=O)c3ccccc3C2=O)c(Cl)c1',
#   'reg_label': 5.72,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cn1cccc1C(=O)Nc1ccc(N2C(=O)c3ccccc3C2=O)c(Cl)c1',
#   'reg_label': 5.28,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1cc[nH]c1C(=O)Nc1ccc(N2C(=O)c3ccccc3C2=O)c(Cl)c1',
#   'reg_label': 5.465,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1ccoc1C(=O)Nc1ccc(N2C(=O)c3ccc(F)cc3C2=O)cc1F',
#   'reg_label': 6.21,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'Cc1ccoc1C(=O)Nc1ccc(N2C(=O)c3cccc(F)c3C2=O)cc1F',
#   'reg_label': 6.155,
#   'assay_id': 1550577,
#   'cls_label': 1,
#   'domain_id': 92},
#  {'smiles': 'CCC(C)(C)C(=O)N(O)Cc1cc(F)cc(F)c1F',
#   'reg_label': 7.13,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CCC(C)(C)C(=O)N(O)Cc1cc(F)c(F)c(F)c1',
#   'reg_label': 7.31,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CCC(C)(C)C(=O)N(O)Cc1ccc(F)c(F)c1F',
#   'reg_label': 6.58,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CCC(C)(C)C(=O)N(O)Cc1ccc(F)c(F)c1',
#   'reg_label': 7.25,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CCC(C)(C)C(=O)N(O)Cc1ccc(F)cc1F',
#   'reg_label': 6.7,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CCC(C)(C)C(=O)N(O)Cc1ccc(F)cc1',
#   'reg_label': 7.19,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CCC(C)(C)C(=O)N(O)Cc1ccccc1',
#   'reg_label': 7.55,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CCC(C)(C)C(=O)NC(CO)c1ccccc1',
#   'reg_label': 5.97,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CC1CCCC(C)N1C(=O)N(C)Cc1cc(F)cc(F)c1F',
#   'reg_label': 5.82,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CN(Cc1cc(F)cc(F)c1F)C(=O)C1(C)CCCCC1',
#   'reg_label': 6.31,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CN(Cc1cc(F)cc(F)c1F)C(=O)C1(C(F)(F)F)CCCC1',
#   'reg_label': 5.91,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CN(Cc1cc(F)cc(F)c1F)C(=O)C1(C(F)(F)F)CCC1',
#   'reg_label': 6.18,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CN(Cc1cc(F)cc(F)c1F)C(=O)C1CCC1',
#   'reg_label': 5.08,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CN(Cc1cc(F)cc(F)c1F)C(=O)C(C)(C)C',
#   'reg_label': 7.01,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CCC(C)(C)C(=O)N(C)Cc1ccco1',
#   'reg_label': 6.2,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CCC(C)(C)C(=O)N(C)Cc1cc(C)c(C)s1',
#   'reg_label': 5.88,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CCC(C)(C)C(=O)N(C)Cc1ccc(C)s1',
#   'reg_label': 6.42,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CCC(C)(C)C(=O)N(C)Cc1sccc1C',
#   'reg_label': 5.6,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CCC(C)(C)C(=O)N(C)Cc1cccs1',
#   'reg_label': 6.66,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CCC(C)(C)C(=O)N(C)Cc1cccnc1',
#   'reg_label': 5.76,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CCC(C)(C)C(=O)N(C)Cc1c(F)cc(F)cc1F',
#   'reg_label': 5.9,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CCC(C)(C)C(=O)N(C)Cc1cc(F)cc(F)c1F',
#   'reg_label': 7.92,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CCC(C)(C)C(=O)N(C)Cc1cc(F)ccc1F',
#   'reg_label': 7.44,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CCC(C)(C)C(=O)N(C)Cc1ccc(F)cc1F',
#   'reg_label': 6.2,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': 'CCC(C)(C)C(=O)N(C)Cc1cccc(F)c1F',
#   'reg_label': 7.24,
#   'assay_id': 1644186,
#   'cls_label': 1,
#   'domain_id': 103},
#  {'smiles': '

#   'assay_id': 1712855,
#   'cls_label': 1,
#   'domain_id': 118},
#  {'smiles': 'Cn1cc(-c2ccc(CN3CC(C(=O)N[C@H]4CCCC[C@@H]4O)Oc4ccccc43)cn2)cn1',
#   'reg_label': 6.705,
#   'assay_id': 1712855,
#   'cls_label': 1,
#   'domain_id': 118},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NN2CCOCC2)C(=O)c2cccc(C)c21',
#   'reg_label': 6.32,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NN2CCCCC2)C(=O)c2cccc(C)c21',
#   'reg_label': 6.0,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NCC2CCC2)C(=O)c2cccc(C)c21',
#   'reg_label': 6.66,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NCC2CC2)C(=O)c2cccc(C)c21',
#   'reg_label': 6.9,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NC2CC2)C(=O)c2cccc(C)c21',
#   'reg_label': 6.3,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NC2CCCC2)C(=O)c2cccc(C)c21',
#   'reg_label': 7.24,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/Nc2ccccn2)C(=O)c2cccc(C)c21',
#   'reg_label': 5.62,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NC23CC4CC(CC(C4)C2)C3)C(=O)c2cccc(C)c21',
#   'reg_label': 6.5,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCCCC(C)(C)c1ccc([C@@H]2C[C@H](O)CC[C@H]2CCCO)c(O)c1',
#   'reg_label': 7.51,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'O=C(NCC1CCOCC1)c1cnc(Nc2ccc(Cl)cc2Cl)nc1C(F)(F)F',
#   'reg_label': 6.36,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NC2CCCCC2)C(=O)c2cccc(OC)c21',
#   'reg_label': 5.85,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NC2CCCCC2)C(=O)c2cccc(CC)c21',
#   'reg_label': 6.1,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'C=CCCN1C(=O)/C(=C/NC2CCCCC2)C(=O)c2cccc(C)c21',
#   'reg_label': 6.13,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'Cc1cccc2c1N(CC1CC1)C(=O)/C(=C/NC1CCCCC1)C2=O',
#   'reg_label': 6.17,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCCN1C(=O)/C(=C/NC2CCCCC2)C(=O)c2cccc(C)c21',
#   'reg_label': 6.5,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NC2CCCCC2)C(=O)c2cccc(C)c21',
#   'reg_label': 7.03,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCN1C(=O)/C(=C/NC2CCCCC2)C(=O)c2cccc(C)c21',
#   'reg_label': 6.3,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCN1C(=O)/C(=C/NC2CCCCC2)C(=O)c2cccc(C)c21',
#   'reg_label': 4.75,
#   'assay_id': 1502230,
#   'cls_label': 0,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NC2CCCCC2)C(=O)c2c(C)cccc21',
#   'reg_label': 6.47,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCCN1C(=O)/C(=C/NC2CCCCC2)C(=O)c2ccccc21',
#   'reg_label': 6.33,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NC2CCCCC2)C(=O)c2ccccc21',
#   'reg_label': 5.8,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'C=CCCN1C(=O)/C(=C/NC(C)(C)C)C(=O)c2cccc(C)c21',
#   'reg_label': 7.12,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'Cc1cccc2c1N(CC1CC1)C(=O)/C(=C/NC(C)(C)C)C2=O',
#   'reg_label': 6.98,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCN1C(=O)/C(=C/NC(C)(C)C)C(=O)c2cccc(C)c21',
#   'reg_label': 7.44,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NC(C)(C)CC)C(=O)c2cccc(C)c21',
#   'reg_label': 7.12,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NC(CC)CC)C(=O)c2cccc(C)c21',
#   'reg_label': 6.95,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NC(C)CCC)C(=O)c2cccc(C)c21',
#   'reg_label': 6.94,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NC(C)C(C)C)C(=O)c2cccc(C)c21',
#   'reg_label': 7.08,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NC(C)(C)CO)C(=O)c2cccc(C)c21',
#   'reg_label': 7.385,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NC(C)(C)C)C(=O)c2cccc(C)c21',
#   'reg_label': 7.7,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN1C(=O)/C(=C/NCC(C)C)C(=O)c2cccc(C)c21',
#   'reg_label': 7.355,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'CCCCN/C=C1\\C(=O)c2cccc(C)c2N(CCCC)C1=O',
#   'reg_label': 7.04,
#   'assay_id': 1502230,
#   'cls_label': 1,
#   'domain_id': 85},
#  {'smiles': 'O=C(NCC1CCNCC1)c1ccccc1-c1nc(Cl)cs1',
#   'reg_label': 6.6,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'O=C(NCC1CCNCC1)c1cccc(F)c1-c1cccc(Cl)c1',
#   'reg_label': 5.3,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'O=C(NCC1CCNCC1)c1cc(F)ccc1-c1cccc(Cl)c1',
#   'reg_label': 7.3,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'O=C(NCC1CCNCC1)c1c(F)cccc1-c1cccc(Cl)c1',
#   'reg_label': 7.8,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'O=C(NCC1CCNCC1)c1ccc(Cl)cc1-c1cccc(Cl)c1',
#   'reg_label': 7,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'O=C(NCC1CCNCC1)c1cc(Cl)ccc1-c1cccc(Cl)c1',
#   'reg_label': 7,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'O=C(NCC1CCNCC1)c1c(Cl)cccc1-c1cccc(Cl)c1',
#   'reg_label': 7.2,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'Cc1ccc(C(=O)NCC2CCNCC2)c(-c2cccc(Cl)c2)c1',
#   'reg_label': 6.8,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'Cc1ccc(-c2cccc(Cl)c2)c(C(=O)NCC2CCNCC2)c1',
#   'reg_label': 6,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'O=C(NCCC1CCNCC1)c1ccccc1-c1cccc(Cl)c1',
#   'reg_label': 5.5,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'O=C(CC1CCNCC1)Nc1ccccc1-c1cccc(Cl)c1',
#   'reg_label': 5.1,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'OC(CCC1CCNCC1)c1ccccc1-c1cccc(Cl)c1',
#   'reg_label': 9,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'Clc1cccc(-c2ccccc2/C=C/CC2CCNCC2)c1',
#   'reg_label': 6,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'CC(=O)N(Cc1ccccc1-c1cccc(Cl)c1)CC1CCNCC1',
#   'reg_label': 6.4,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'O=C(NCc1ccccc1-c1cccc(Cl)c1)C1CCNCC1',
#   'reg_label': 6.3,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'O=C(Cc1ccccc1-c1cccc(Cl)c1)NC1CCNCC1',
#   'reg_label': 6.8,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'CN(C(=O)Cc1ccccc1-c1cccc(Cl)c1)C1CCNCC1',
#   'reg_label': 7.3,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'CS(=O)(=O)N(Cc1c(F)cccc1-c1cccc(Cl)c1)CC1CCNCC1',
#   'reg_label': 5.8,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'O=S(=O)(CCC1CCNCC1)c1ccccc1-c1cccc(Cl)c1',
#   'reg_label': 7.2,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'Fc1cccc(-c2cc(Cl)ccc2Cl)c1-c1nc(C2CCNCC2)no1',
#   'reg_label': 6.3,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'O=C(NCC1CCNCC1)c1c(F)cccc1-c1cc(Cl)ccc1Cl',
#   'reg_label': 7.5,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'C[C@H]1CNCC[C@@H]1CNC(=O)c1c(F)cccc1-c1cccc(Cl)c1',
#   'reg_label': 9.1,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'C[C@H]1CNCC[C@H]1CNC(=O)c1c(F)cccc1-c1cccc(Cl)c1',
#   'reg_label': 7.7,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'O=C(NCC1=CCNCC1)c1c(F)cccc1-c1cccc(Cl)c1',
#   'reg_label': 8.5,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'CC1CNCC=C1CNC(=O)c1c(-c2cccc(Cl)c2)ccc(Cl)c1F',
#   'reg_label': 6.8,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'O=C(NCC1CCNCC1)c1c(-c2cccc(Cl)c2)ccc(Cl)c1F',
#   'reg_label': 7.6,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'CC[C@H]1CNCC[C@@H]1CNC(=O)c1c(F)cccc1-c1cccc(Cl)c1',
#   'reg_label': 7.4,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'O=C(NC[C@H]1CCNC[C@H]1F)c1c(F)cccc1-c1cccc(Cl)c1',
#   'reg_label': 6.8,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'O=C(NCC1=C(F)CNCC1)c1c(-c2cccc(Cl)c2)ccc(Cl)c1F',
#   'reg_label': 6.8,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'O=C(NCC1(F)CCNCC1)c1c(F)cccc1-c1cccc(Cl)c1',
#   'reg_label': 7.2,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'C[C@H]1CNCC[C@]1(F)CNC(=O)c1c(F)cccc1-c1cccc(Cl)c1',
#   'reg_label': 8,
#   'assay_id': 635221,
#   'cls_label': 1,
#   'domain_id': 34},
#  {'smiles': 'O=C(Nc1ncc(S(=O)(=O)Cc2ccccc2Cl)s1)c1ccccn1',
#   'reg_label': 6.72,
#   'assay_id': 1578996,
#   'cls_label': 1,
#   'domain_id': 96},
#  {'smiles': 'Cc1nc(NC(=O)c2ccccn2)sc1S(=O)(=O)Cc1ccccc1Cl',
#   'reg_label': 6.35,
#   'assay_id': 1578996,
#   'cls_label': 1,
#   'domain_id': 96},
#  {'smiles': 'O=C(Nc1ncc(S(=O)(=O)Cc2ccc(Cl)cc2F)s1)c1ccccn1',
#   'reg_label': 7.08,
#   'assay_id': 1578996,
#   'cls_label': 1,
#   'domain_id': 96},
#  {'smiles': 'Cc1nc(NC(=O)c2ccccn2)sc1S(=O)(=O)Cc1ccc(Cl)cc1F',
#   'reg_label': 5.38,
#   'assay_id': 1578996,
#   'cls_label': 1,
#   'domain_id': 96},
#  {'smiles': 'CCc1nc(NC(=O)c2ccccn2)sc1S(=O)(=O)Cc1ccc(Cl)cc1F',
#   'reg_label': 6.66,
#   'assay_id': 1578996,
#   'cls_label': 1,
#   'domain_id': 96},
#  {'smiles': 'Cc1nc(NC(=O)c2ccccn2)sc1S(=O)(=O)Cc1ccc(F)cc1F',
#   'reg_label': 6.26,
#   'assay_id': 1578996,
#   'cls_label': 1,
#   'domain_id': 96},
#  {'smiles': 'Cc1nc(NC(=O)c2ccccn2)sc1S(=O)(=O)Cc1c(F)cccc1F',
#   'reg_label': 6.53,
#   'assay_id': 1578996,
#   'cls_label': 1,
#   'domain_id': 96},
#  {'smiles': 'CCc1nc(NC(=O)c2ccccn2)sc1S(=O)(=O)Cc1c(F)cccc1F',
#   'reg_label': 6.82,
#   'assay_id': 1578996,
#   'cls_label': 1,
#   'domain_id': 96},
#  {'smiles': 'O=C(Nc1ccn(S(=O)(=O)Cc2cccc(F)c2)c1)c1ccccn1',
#   'reg_label': 6.24,
#   'assay_id': 1578996,
#   'cls_label': 1,
#   'domain_id': 96},
#  {'smiles': 'O=C(Nc1ccn(S(=O)(=O)Cc2ccc(C(F)(F)F)cc2)c1)c1ccccn1',
#   'reg_label': 6.725,
#   'assay_id': 1578996,
#   'cls_label': 1,
#   'domain_id': 96},
#  {'smiles': 'Cc1cccc(CS(=O)(=O)n2ccc(NC(=O)c3ccccn3)c2)c1',
#   'reg_label': 5.38,
#   'assay_id': 1578996,
#   'cls_label': 1,
#   'domain_id': 96},
#  {'smiles': 'O=C(Nc1ccn(S(=O)(=O)Cc2ccc(F)cc2Cl)c1)c1ccccn1',
#   'reg_label': 7.075,
#   'assay_id': 1578996,
#   'cls_label': 1,
#   'domain_id': 96},
# ...
#   'assay_id': 688381,
#   'cls_label': 1,
#   'domain_id': 39},
#  {'smiles': 'CCCc1ccc(C(=O)NC(=O)c2ccccc2O)cc1',
#   'reg_label': 4.83,
#   'assay_id': 688381,
#   'cls_label': 0,
#   'domain_id': 39},
#  {'smiles': 'COc1cc(N2CCCC2)c(OC)cc1/C=C1\\SC(=O)N(C)C1=O',
#   'reg_label': 5.62,
#   'assay_id': 688381,
#   'cls_label': 1,
#   'domain_id': 39},
#  {'smiles': 'COc1cc(/C=C(\\C#N)c2nc3ccccc3[nH]2)cc(OC)c1O',
#   'reg_label': 5.245,
#   'assay_id': 688381,
#   'cls_label': 1,
#   'domain_id': 39},
#  {'smiles': 'Cc1cc2nc3c(=O)n(CCc4ccccc4)c(=O)[nH]c3nc2cc1N',
#   'reg_label': 5.33,
#   'assay_id': 688381,
#   'cls_label': 1,
#   'domain_id': 39},
#  {'smiles': 'CC(C)(C)c1ccc(C(=O)NC(=S)NNC(=O)c2cccs2)cc1',
#   'reg_label': 6.66,
#   'assay_id': 688381,
#   'cls_label': 1,
#   'domain_id': 39},
#  {'smiles': 'O=c1oc2c3c4c(cc2c(C(F)(F)F)c1CCN1CCOCC1)CCCN4CCC3',
#   'reg_label': 5.34,
#   'assay_id': 688381,
#   'cls_label': 1,
#   'domain_id': 39},
#  {'smiles': 'O=C(Nc1nnc(-c2cccs2)o1)c1cccc(C(F)(F)F)c1',
#   'reg_label': 5.415,
#   'assay_id': 688381,
#   'cls_label': 1,
#   'domain_id': 39},
#  {'smiles': 'C=CCn1c(=O)[nH]c2nc3cc(/N=C/N(C)C)c(C)cc3nc2c1=O',
#   'reg_label': 5.36,
#   'assay_id': 688381,
#   'cls_label': 1,
#   'domain_id': 39},
#  {'smiles': 'C=C1C(=O)C=C2CN(C(=O)c3ccccc3)[C@@](Cc3ccc(F)cc3)(C(=O)OC)[C@@H]12',
#   'reg_label': 5.95,
#   'assay_id': 688381,
#   'cls_label': 1,
#   'domain_id': 39},
#  {'smiles': 'CN1CCS/C1=C/C=C1\\SC(=S)N(CC(=O)O)C1=O',
#   'reg_label': 5.07,
#   'assay_id': 688381,
#   'cls_label': 1,
#   'domain_id': 39},
#  {'smiles': 'CC(C)/C=C1\\CC/C(=C\\c2ccc(N(C)C)cc2)C1=O',
#   'reg_label': 6.005,
#   'assay_id': 688381,
#   'cls_label': 1,
#   'domain_id': 39},
#  {'smiles': 'CN1CCS/C1=C\\C=C1/SC(=S)N(CC(=O)O)C1=O',
#   'reg_label': 5.1899999999999995,
#   'assay_id': 688381,
#   'cls_label': 1,
#   'domain_id': 39},
#  {'smiles': 'Cc1cc(-c2cnc(-c3sc(C)c4c3C[C@@H]3[C@H]4C3(C)C)s2)cc(C)c1OCC(O)CO',
#   'reg_label': 7.42,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'Cc1cc(-c2nnc(-c3sc(C)c4c3C[C@@H]3[C@H]4C3(C)C)s2)cc(C)c1OCC(O)CO',
#   'reg_label': 7.47,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'Cc1cc(CCC(=O)c2sc(C)c3c2C[C@@H]2[C@H]3C2(C)C)cc(C)c1OCC(=O)O',
#   'reg_label': 6.52,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'Cc1cc(CCC(=O)c2sc(C)c3c2C[C@@H]2[C@H]3C2(C)C)c(C)c(C)c1OCCO',
#   'reg_label': 7.62,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'CCc1cc(CCC(=O)c2sc(C)c3c2C[C@@H]2[C@H]3C2(C)C)cc(C)c1OCCO',
#   'reg_label': 8.36,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'COc1cc(CCC(=O)c2sc(C)c3c2C[C@@H]2[C@H]3C2(C)C)cc(OC)c1OCCO',
#   'reg_label': 6.63,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'COc1cc(CCC(=O)c2sc(C)c3c2C[C@@H]2[C@H]3C2(C)C)ccc1OCCO',
#   'reg_label': 7.54,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'Cc1cc(OCCO)cc(C)c1CCC(=O)c1sc(C)c2c1C[C@@H]1[C@H]2C1(C)C',
#   'reg_label': 6.04,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'COc1cc(OCCO)cc(OC)c1CCC(=O)c1sc(C)c2c1C[C@@H]1[C@H]2C1(C)C',
#   'reg_label': 5.51,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'COc1cc(OCCO)ccc1CNC(=O)c1sc(C)c2c1C[C@@H]1[C@H]2C1(C)C',
#   'reg_label': 6.55,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'Cc1sc(C(=O)NCc2ccc(OCCO)cc2)c2c1[C@H]1[C@@H](C2)C1(C)C',
#   'reg_label': 5.75,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'COc1ccc(OC)c(CNC(=O)c2sc(C)c3c2C[C@@H]2[C@H]3C2(C)C)c1',
#   'reg_label': 5.14,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'COc1ccc(CNC(=O)c2sc(C)c3c2C[C@@H]2[C@H]3C2(C)C)c(OC)c1',
#   'reg_label': 6.35,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'COc1cccc(CNC(=O)c2sc(C)c3c2C[C@@H]2[C@H]3C2(C)C)c1OC',
#   'reg_label': 5.13,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'COc1ccccc1CNC(=O)c1sc(C)c2c1C[C@@H]1[C@H]2C1(C)C',
#   'reg_label': 6.28,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'COc1ccccc1CNC(=O)C1=NN(C)C2C1C[C@@H]1[C@H]2C1(C)C',
#   'reg_label': 5.07,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'COc1ccccc1CCC(=O)n1cc(C)c2c1C[C@@H]1[C@H]2C1(C)C',
#   'reg_label': 7.52,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'COc1ccccc1CNC(=O)n1nc(C)c2c1C[C@@H]1[C@H]2C1(C)C',
#   'reg_label': 7.01,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'COc1ccccc1CCC(=O)n1nc(C)c2c1C[C@@H]1[C@H]2C1(C)C',
#   'reg_label': 8.42,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'Cc1nn(C(=O)/C=C/c2cc(F)ccc2F)c2c1[C@H]1[C@@H](C2)C1(C)C',
#   'reg_label': 8.52,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'Cc1nn(C(=O)/C=C/c2ccccc2)c2c1[C@H]1[C@@H](C2)C1(C)C',
#   'reg_label': 7.8,
#   'assay_id': 1285820,
#   'cls_label': 1,
#   'domain_id': 75},
#  {'smiles': 'CC(C)(N)C(=O)N[C@H](COCc1ccccc1)C(=O)N1CCC2(CC1)CN(S(C)(=O)=O)c1ccccc12',
#   'reg_label': 9.139999999999999,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'CNC(C)(C)C/C=C/C(=O)N(C)[C@H](Cc1ccc2ccccc2c1)C(=O)N(C)CCc1ccccc1',
#   'reg_label': 8.52,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'NC(=O)[C@@H](NC(=O)[C@@H](Cc1ccc2ccccc2c1)NC(=O)[C@@H](Cc1ccc2ccccc2c1)NC(=O)C1CCNCC1)c1ccccc1',
#   'reg_label': 9.55,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'O=C(N[C@H](Cc1ccc2ccccc2c1)C(=O)N[C@@H](CO)Cc1ccc2ccccc2c1)C1CCNCC1',
#   'reg_label': 8.74,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'O=C(N[C@H](Cc1ccc2ccccc2c1)C(=O)N[C@@H](CO)Cc1c[nH]c2ccccc12)C1CCNCC1',
#   'reg_label': 8.0,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'NCCCCNC(=O)[C@@H](Cc1ccc2ccccc2c1)NC(=O)[C@@H](Cc1ccc2ccccc2c1)NC(=O)C1CCNCC1',
#   'reg_label': 7.77,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'CCN(CC)CCN1C(=O)[C@@](O)(c2ccc3ccccc3c2)c2c1cc(C(N)=O)cc2C(F)(F)F',
#   'reg_label': 7.745,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'CCN(CC)CCN1C(=O)[C@@](O)(c2ccc3ccccc3c2)c2c1cc(C#CCCC(=O)N(C)C)cc2C(F)(F)F',
#   'reg_label': 7.52,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'CCN(CC)CCN1C(=O)[C@@](O)(c2ccc3ccccc3c2)c2c1cc(C#CCCC(=O)N1CCOCC1)cc2C(F)(F)F',
#   'reg_label': 7.52,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'CCN(CC)CCN1C(=O)[C@@](O)(c2ccc3ccccc3c2)c2c(Br)cccc21',
#   'reg_label': 7.11,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'CC(C)(N)C(=O)N[C@H](CCCc1ccccc1)C(=O)N1CCN(c2ccccc2NS(=O)(=O)CC(=O)O)CC1',
#   'reg_label': 8.64,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'COC(=O)CS(=O)(=O)Nc1ccccc1N1CCN(C(=O)[C@@H](CCCc2ccccc2)NC(=O)C(C)(C)N)CC1',
#   'reg_label': 8.35,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'CC(C)S(=O)(=O)Nc1ccccc1N1CCN(C(=O)[C@@H](CCCc2ccccc2)NC(=O)C(C)(C)N)CC1',
#   'reg_label': 8.55,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'CC(C)(N)C(=O)N[C@H](CCCc1ccccc1)C(=O)N1CCN(c2ccccc2NS(C)(=O)=O)CC1',
#   'reg_label': 8.2,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'Cc1ccccc1N1CCN(C(=O)[C@@H](CCCc2ccccc2)NC(=O)C(C)(C)N)CC1',
#   'reg_label': 7.425,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'NCC(O)CNC(=O)[C@@H](Cc1cccc2ccccc12)NC(=O)CCCN1C(=O)CCSc2ccccc21',
#   'reg_label': 8.85,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'NCCNC(=O)[C@@H](Cc1cccc2ccccc12)NC(=O)CCN1C(=O)CCS(=O)(=O)c2ccccc21',
#   'reg_label': 8.11,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'CCNC(=O)[C@]1(Cc2ccccc2)CCCN(C(=O)[C@@H](Cc2c[nH]c3ccccc23)NC(=O)C(C)(C)N)C1',
#   'reg_label': 9.1,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'CCOC(=O)[C@]1(Cc2ccccc2)CCCN(C(=O)[C@@H](Cc2c[nH]c3ccccc23)NC(=O)C(C)(C)N)C1',
#   'reg_label': 8.8,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'CCOC(=O)[C@@H](CCc1ccccc1)NC(=O)[C@@H](Cc1c[nH]c2ccccc12)NC(=O)C(C)(C)N',
#   'reg_label': 8.52,
#   'assay_id': 454761,
#   'cls_label': 1,
#   'domain_id': 15},
#  {'smiles': 'COc1ccc(CCC(=O)c2sc3nnc(C)c(C)c3c2N)cc1F',
#   'reg_label': 6.5075,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'Cc1cc(C)c2c(N)c(C(=O)CCc3ccncc3)sc2n1',
#   'reg_label': 6.295,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'Nc1c(C(=O)c2ccncc2)sc2nc(O)c3c(c12)CCCC3',
#   'reg_label': 7.0075,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'Cc1nnc2sc(C(=O)c3ccncc3)c(N)c2c1C',
#   'reg_label': 5.75,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'Cc1nnc2sc(C(=O)c3cccnc3)c(N)c2c1C',
#   'reg_label': 6.68,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'Cc1nnc2sc(C(=O)c3ccc(F)cc3F)c(N)c2c1C',
#   'reg_label': 6.450000000000001,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'COc1ccc(C(=O)c2sc3nnc(C)c(C)c3c2N)cc1',
#   'reg_label': 6.015,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'Cc1nnc2sc(C(=O)c3ccccc3)c(N)c2c1C',
#   'reg_label': 6.885000000000001,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'Cc1nc2sc(C(=O)c3cccnc3)c(N)c2c(C)c1Cl',
#   'reg_label': 6.68,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'Cc1nc2sc(C(=O)c3ccccc3)c(N)c2c(C)c1Cl',
#   'reg_label': 6.295,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'Cc1cc(C)c2c(N)c(C(=O)c3ccncc3)sc2n1',
#   'reg_label': 5.9399999999999995,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'Cc1cc(C)c2c(N)c(C(=O)c3ccc(F)cc3F)sc2n1',
#   'reg_label': 5.824999999999999,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'Cc1cc(C)c2c(N)c(C(=O)c3ccc(F)c(Cl)c3)sc2n1',
#   'reg_label': 6.665,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'COc1ccc(C(=O)c2sc3nc(C)cc(C)c3c2N)cc1',
#   'reg_label': 6.3149999999999995,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'Cc1cc(C)c2c(N)c(C(=O)c3ccc(O)cc3)sc2n1',
#   'reg_label': 6.4350000000000005,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'Cc1cc(C)c2c(N)c(C(=O)c3ccccc3)sc2n1',
#   'reg_label': 5.9350000000000005,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'Cc1nc2sc(C(=O)c3ccccc3)c(N)c2c(C)c1C',
#   'reg_label': 6.9350000000000005,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'Nc1c(C(=O)c2ccncc2)sc2nc(OCc3ccncc3)c3c(c12)CCC3',
#   'reg_label': 6.220000000000001,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'Nc1c(C(=O)c2ccncc2)sc2nc(OCCN3CCOCC3)c3c(c12)CCC3',
#   'reg_label': 6.75,
#   'assay_id': 1933830,
#   'cls_label': 1,
#   'domain_id': 138},
#  {'smiles': 'Cn1cc(-c2ccc(CN3C(=O)C4(CCN(CCF)C4)c4ccccc43)c(F)c2)cn1',
#   'reg_label': 5.39,
#   'assay_id': 943799,
#   'cls_label': 1,
#   'domain_id': 67},
#  {'smiles': 'CN1CCC2(C1)C(=O)N(Cc1ccc(-c3cnn(C)c3)cc1F)c1ccccc12',
#   'reg_label': 5.5249999999999995,
#   'assay_id': 943799,
#   'cls_label': 1,
#   'domain_id': 67},
#  {'smiles': 'Cn1cc(-c2cc(F)c(CN3C(=O)C4(CCN(C5CCCC5)C4)c4ccccc43)cc2F)cn1',
#   'reg_label': 5.39,
#   'assay_id': 943799,
#   'cls_label': 1,
#   'domain_id': 67},
#  {'smiles': 'Cn1cc(-c2cc(F)c(CN3C(=O)C4(CCN(C5CCCC5)C4)c4ccccc43)c(F)c2)cn1',
#   'reg_label': 5.58,
#   'assay_id': 943799,
#   'cls_label': 1,
#   'domain_id': 67},
#  {'smiles': 'Cn1cc(-c2ccc(CN3C(=O)C4(CCN(C5CCCC5)C4)c4ccccc43)cc2F)cn1',
#   'reg_label': 5.7,
#   'assay_id': 943799,
#   'cls_label': 1,
#   'domain_id': 67},
#  {'smiles': 'Cc1nn(C)cc1-c1ccc(CN2C(=O)C3(CCN(C4CCCC4)C3)c3ccccc32)c(F)c1',
#   'reg_label': 5.52,
#   'assay_id': 943799,
#   'cls_label': 1,
#   'domain_id': 67},
#  {'smiles': 'Cn1cc(-c2ccc(CN3C(=O)C4(CCN(c5ncccn5)C4)c4ccccc43)c(F)c2)cn1',
#   'reg_label': 5.605,
#   'assay_id': 943799,
#   'cls_label': 1,
#   'domain_id': 67},
#  {'smiles': 'Cn1cc(-c2ccc(CN3C(=O)C4(CCN(C(=O)C5CCCCC5)C4)c4ccccc43)c(F)c2)cn1',
#   'reg_label': 5.3,
#   'assay_id': 943799,
#   'cls_label': 1,
#   'domain_id': 67},
#  {'smiles': 'Cn1cc(-c2ccc(CN3C(=O)C4(CCN(C(=O)C5CCC5)C4)c4ccccc43)c(F)c2)cn1',
#   'reg_label': 5.2,
#   'assay_id': 943799,
#   'cls_label': 1,
#   'domain_id': 67},
#  {'smiles': 'CCN1CCC2(C1)C(=O)N(Cc1ccc(-c3cnn(C)c3)cc1F)c1ccccc12',
#   'reg_label': 5.495,
#   'assay_id': 943799,
#   'cls_label': 1,
#   'domain_id': 67},
#  {'smiles': 'Cn1cc(-c2ccc(CN3C(=O)C4(CCN(C5CCCC5)C4)c4ccccc43)c(F)c2)cn1',
#   'reg_label': 5.654999999999999,
#   'assay_id': 943799,
#   'cls_label': 1,
#   'domain_id': 67},
#  {'smiles': 'Cn1cc(-c2ccc(CN3C(=O)C4(CCN(C5CCCCCC5)C4)c4ccccc43)c(F)c2)cn1',
#   'reg_label': 5.125,
#   'assay_id': 943799,
#   'cls_label': 1,
#   'domain_id': 67},
#  {'smiles': 'Cn1cc(-c2ccc(CN3C(=O)C4(CCN(C5CCCCC5)C4)c4ccccc43)c(F)c2)cn1',
#   'reg_label': 5.285,
#   'assay_id': 943799,
#   'cls_label': 1,
#   'domain_id': 67},
#  {'smiles': 'CN1CCC2(CC1)C(=O)N(Cc1ccc(-c3cnn(C)c3)cc1F)c1ccccc12',
#   'reg_label': 5.42,
#   'assay_id': 943799,
#   'cls_label': 1,
#   'domain_id': 67},
#  {'smiles': 'Cn1cc(-c2ccc(CN3C(=O)C4(OCCO4)c4ccccc43)c(F)c2)cn1',
#   'reg_label': 5.7,
#   'assay_id': 943799,
#   'cls_label': 1,
#   'domain_id': 67},
#  {'smiles': 'Cn1cc(-c2ccc(CN3C(=O)C(=O)c4ccccc43)c(F)c2)cn1',
#   'reg_label': 6.22,
#   'assay_id': 943799,
#   'cls_label': 1,
#   'domain_id': 67},
#  {'smiles': 'Cn1cc(-c2ccc(CN3C(=O)C4(CCN(C5CCCC5)C4)c4ccccc43)cc2)cn1',
(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](CCCNC(=N)N)C(=O)N[C@@H](Cc1ccc(O)cc1)C(N)=O',
#   'reg_label': 7.315,
#   'assay_id': 1988067,
#   'cls_label': 1,
#   'domain_id': 140},
#  {'smiles': 'CC(=O)N[C@@H](CCCNC(=N)N)C(=O)N[C@@H](Cc1ccccc1)C(=O)N[C@@H](CCCNC(=N)N)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](CCCNC(=N)N)C(=O)N[C@@H](Cc1ccc(O)cc1)C(N)=O',
#   'reg_label': 6.38,
#   'assay_id': 1988067,
#   'cls_label': 1,
#   'domain_id': 140},
#  ...]

# %%
import io
from PIL import Image
from rdkit import Chem
from rdkit.Chem import rdDepictor
from rdkit.Chem.Draw import rdMolDraw2D

import random
import numpy as np
import matplotlib.pyplot as plt

# smiles = 'CCCCNc1nc(NCC2CC2)nc(N2CCC[C@@H]2CNS(=O)(=O)c2ccc(CCC)cc2)n1' 
# m = Chem.MolFromSmiles(smiles)

def moltosvg(mol, molSize = (500,500), kekulize = True):
    mc = Chem.Mol(mol.ToBinary())
    if kekulize:
        try:
            Chem.Kekulize(mc)
        except:
            mc = Chem.Mol(mol.ToBinary())
    if not mc.GetNumConformers():
        rdDepictor.Compute2DCoords(mc)
    drawer = rdMolDraw2D.MolDraw2DCairo(molSize[0],molSize[1])
    drawer.DrawMolecule(mc)
    drawer.FinishDrawing()
    bts = drawer.GetDrawingText()
    im = Image.open(io.BytesIO(bts))
    return im

def display_multiple_img(images, rows = 1, cols=1):
    figure, ax = plt.subplots(nrows=rows,ncols=cols, figsize=(10,5) )
    for ind,title in enumerate(images):
        ax.ravel()[ind].imshow(images[title])
        ax.ravel()[ind].set_title(title)
        ax.ravel()[ind].set_axis_off()
    plt.tight_layout()
    plt.show()
    
# moltosvg(m)

# %%
# train examples:
train_example = random.sample(train, 5)
total_images = 5
images = {"Domain {}".format(item["domain_id"]) : moltosvg(Chem.MolFromSmiles(item["smiles"])) for i, item in enumerate(train_example)}
# ood examples:
ood_test_example = random.sample(ood_test, 5)
total_images = 5
images.update({"Domain {}".format(item["domain_id"]) : moltosvg(Chem.MolFromSmiles(item["smiles"])) for i, item in enumerate(ood_test_example)})
display_multiple_img(images, 2, 5)

# %% [markdown]
# ### Train an OOD algorithm
# Finally, let us initialize the dataset and algorithm, then train a new model! For convenience, we modify the settings based on a built-in algorithm config.

# %%
from mmcv import Config
from drugood.apis import set_random_seed

cfg = Config.fromfile('../configs/algorithms/erm/lbap_core_ec50_assay_erm.py')

ann_file = 'data/lbap_core_ec50_assay_custom.json'
cfg.data.train.ann_file = ann_file
cfg.data.ood_val.ann_file= ann_file
cfg.data.iid_val.ann_file= ann_file
cfg.data.ood_test.ann_file= ann_file
cfg.data.iid_test.ann_file= ann_file

cfg.runner.max_epochs=5

# Set seed thus the results are more reproducible
cfg.seed = 0
cfg.gpu_ids = range(1)

cfg.work_dir = "work_dirs/lbap_core_ec50_assay_custom"

print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# optimizer = dict(type='AdamW', lr=0.0001, weight_decay=0)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(policy='fixed')
# runner = dict(type='EpochBasedRunner', max_epochs=5)
# evaluation = dict(metric=['accuracy', 'auc'])
# checkpoint_config = dict(interval=5)
# log_config = dict(
#     interval=5,
#     hooks=[dict(type='TextLoggerHook'),
#            dict(type='TensorboardLoggerHook')])
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]
# train_pipeline = [
#     dict(type='SmileToGraph', keys=['input']),
#     dict(type='Collect', keys=['input', 'gt_label', 'group'])
# ]
# test_pipeline = [
#     dict(type='SmileToGraph', keys=['input']),
#     dict(type='Collect', keys=['input', 'gt_label', 'group'])
# ]
# dataset_type = 'LBAPDataset'
# ann_file = 'data/lbap_core_ec50_assay.json'
# data = dict(
#     samples_per_gpu=128,
#     workers_per_gpu=4,
#     train=dict(
#         split='train',
#         type='LBAPDataset',
#         ann_file='data/lbap_core_ec50_assay_custom.json',
#         pipeline=[
#             dict(type='SmileToGraph', keys=['input']),
#             dict(type='Collect', keys=['input', 'gt_label', 'group'])
#         ]),
#     ood_val=dict(
#         split='ood_val',
#         type='LBAPDataset',
#         ann_file='data/lbap_core_ec50_assay_custom.json',
#         pipeline=[
#             dict(type='SmileToGraph', keys=['input']),
#             dict(type='Collect', keys=['input', 'gt_label', 'group'])
#         ],
#         rule='greater',
#         save_best='accuracy'),
#     iid_val=dict(
#         split='iid_val',
#         type='LBAPDataset',
#         ann_file='data/lbap_core_ec50_assay_custom.json',
#         pipeline=[
#             dict(type='SmileToGraph', keys=['input']),
#             dict(type='Collect', keys=['input', 'gt_label', 'group'])
#         ]),
#     ood_test=dict(
#         split='ood_test',
#         type='LBAPDataset',
#         ann_file='data/lbap_core_ec50_assay_custom.json',
#         pipeline=[
#             dict(type='SmileToGraph', keys=['input']),
#             dict(type='Collect', keys=['input', 'gt_label', 'group'])
#         ]),
#     iid_test=dict(
#         split='iid_test',
#         type='LBAPDataset',
#         ann_file='data/lbap_core_ec50_assay_custom.json',
#         pipeline=[
#             dict(type='SmileToGraph', keys=['input']),
#             dict(type='Collect', keys=['input', 'gt_label', 'group'])
#         ]))
# model = dict(
#     type='ERM',
#     tasker=dict(
#         type='Classifier',
#         backbone=dict(
#             type='GIN',
#             num_node_emb_list=[39],
#             num_edge_emb_list=[10],
#             num_layers=4,
#             emb_dim=128,
#             readout='sum',
#             JK='last',
#             dropout=0.1),
#         head=dict(
#             type='LinearClsHead',
#             num_classes=2,
#             in_channels=128,
#             loss=dict(type='CrossEntropyLoss'))))
# seed = 0
# gpu_ids = range(0, 1)
# work_dir = 'work_dirs/lbap_core_ec50_assay_custom'

# %%
import mmcv
import os.path as osp
from drugood.apis import set_random_seed
from drugood.datasets import build_dataset
from drugood.models import build_model
from drugood.apis import train_model

# Set seed
set_random_seed(cfg.seed, deterministic=False)

# Build dataset
datasets = [build_dataset(cfg.data.train)]

# Build the ood model
model = build_model(cfg.model)

# Create work_dir
mmcv.mkdir_or_exist(osp.abspath(cfg.work_dir))
train_model(model, datasets, cfg, distributed=False, validate=True)
# Out:
# 2022-03-19 18:21:04,315 - drugood - INFO - start runner...
# 2022-03-19 18:21:04,316 - drugood - INFO - Start running, host: root@VM-121-51-centos, work_dir: /apdcephfs/private_yataobian/dl-research/graph-ood-benchmark/demo/work_dirs/lbap_core_ec50_assay_custom
# 2022-03-19 18:21:04,317 - drugood - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) FixedLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (NORMAL      ) EvalHook
# (NORMAL      ) EvalHook
# (NORMAL      ) EvalHook
# (NORMAL      ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) FixedLrUpdaterHook
# (NORMAL      ) EvalHook
# (NORMAL      ) EvalHook
# (NORMAL      ) EvalHook
# (NORMAL      ) EvalHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) FixedLrUpdaterHook
# (NORMAL      ) EvalHook
# (NORMAL      ) EvalHook
# (NORMAL      ) EvalHook
# (NORMAL      ) EvalHook
# (LOW         ) IterTimerHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (NORMAL      ) EvalHook
# (NORMAL      ) EvalHook
# (NORMAL      ) EvalHook
# (NORMAL      ) EvalHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (NORMAL      ) EvalHook
# (NORMAL      ) EvalHook
# (NORMAL      ) EvalHook
# (NORMAL      ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_val_epoch:
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# 2022-03-19 18:21:04,318 - drugood - INFO - workflow: [('train', 1)], max: 5 epochs
# 2022-03-19 18:21:04,318 - drugood - INFO - Checkpoints will be saved to /apdcephfs/private_yataobian/dl-research/graph-ood-benchmark/demo/work_dirs/lbap_core_ec50_assay_custom by HardDiskBackend.
# /root/anaconda3/envs/drugood/lib/python3.8/site-packages/mmcv/runner/hooks/evaluation.py:222: UserWarning: runner.meta is None. Creating an empty one.
#   warnings.warn('runner.meta is None. Creating an empty one.')
# 2022-03-19 18:21:08,491 - drugood - INFO - Epoch [1][5/16]	lr: 1.000e-04, eta: 0:01:01, time: 0.819, data_time: 0.516, memory: 250, crossentropy_loss: 6.1246, loss: 6.1246
# 2022-03-19 18:21:08,766 - drugood - INFO - Epoch [1][10/16]	lr: 1.000e-04, eta: 0:00:30, time: 0.056, data_time: 0.021, memory: 250, crossentropy_loss: 3.0851, loss: 3.0851
# 2022-03-19 18:21:09,068 - drugood - INFO - Epoch [1][15/16]	lr: 1.000e-04, eta: 0:00:20, time: 0.060, data_time: 0.027, memory: 250, crossentropy_loss: 2.4531, loss: 2.4531
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>] 1130/1130, 865.8 task/s, elapsed: 1s, ETA:     0s
# 2022-03-19 18:21:10,558 - drugood - INFO - Now best checkpoint is saved as best_ood_val:accuracy_epoch_1.pth.
# 2022-03-19 18:21:10,559 - drugood - INFO - Best ood_val:accuracy is 16.5487 at 1 epoch.
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 730/730, 468.3 task/s, elapsed: 2s, ETA:     0s[                                                  ] 0/1113, elapsed: 0s, ETA:[                                                  ] 0/730, elapsed: 0s, ETA:
# 2022-03-19 18:21:15,372 - drugood - INFO - Epoch(val) [1][6]	ood_val:accuracy: 16.5487, ood_val:auc: 40.8003, iid_val:accuracy: 15.1880, iid_val:auc: 42.5734, ood_test:accuracy: 9.3441, ood_test:auc: 31.6016, iid_test:accuracy: 13.2877, iid_test:auc: 39.1371
# 2022-03-19 18:21:18,547 - drugood - INFO - Epoch [2][5/16]	lr: 1.000e-04, eta: 0:00:21, time: 0.629, data_time: 0.583, memory: 264, crossentropy_loss: 1.8186, loss: 1.8186
# 2022-03-19 18:21:18,934 - drugood - INFO - Epoch [2][10/16]	lr: 1.000e-04, eta: 0:00:17, time: 0.079, data_time: 0.036, memory: 264, crossentropy_loss: 1.4054, loss: 1.4054
# 2022-03-19 18:21:19,230 - drugood - INFO - Epoch [2][15/16]	lr: 1.000e-04, eta: 0:00:13, time: 0.059, data_time: 0.022, memory: 264, crossentropy_loss: 1.1940, loss: 1.1940
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>] 1130/1130, 880.5 task/s, elapsed: 1s, ETA:     0s
# 2022-03-19 18:21:20,670 - drugood - INFO - The previous best checkpoint /apdcephfs/private_yataobian/dl-research/graph-ood-benchmark/demo/work_dirs/lbap_core_ec50_assay_custom/best_ood_val:accuracy_epoch_1.pth was removed
# 2022-03-19 18:21:20,693 - drugood - INFO - Now best checkpoint is saved as best_ood_val:accuracy_epoch_2.pth.
# 2022-03-19 18:21:20,694 - drugood - INFO - Best ood_val:accuracy is 50.6195 at 2 epoch.
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 730/730, 556.8 task/s, elapsed: 1s, ETA:     0s[                                                  ] 0/1113, elapsed: 0s, ETA:[                                                  ] 0/730, elapsed: 0s, ETA:
# 2022-03-19 18:21:25,246 - drugood - INFO - Epoch(val) [2][6]	ood_val:accuracy: 50.6195, ood_val:auc: 51.6418, iid_val:accuracy: 27.6692, iid_val:auc: 44.7544, ood_test:accuracy: 27.5831, ood_test:auc: 64.2833, iid_test:accuracy: 30.2740, iid_test:auc: 48.1984
# 2022-03-19 18:21:28,662 - drugood - INFO - Epoch [3][5/16]	lr: 1.000e-04, eta: 0:00:13, time: 0.677, data_time: 0.626, memory: 264, crossentropy_loss: 1.1240, loss: 1.1240
# 2022-03-19 18:21:29,069 - drugood - INFO - Epoch [3][10/16]	lr: 1.000e-04, eta: 0:00:11, time: 0.083, data_time: 0.043, memory: 264, crossentropy_loss: 1.0169, loss: 1.0169
# 2022-03-19 18:21:29,359 - drugood - INFO - Epoch [3][15/16]	lr: 1.000e-04, eta: 0:00:08, time: 0.058, data_time: 0.021, memory: 264, crossentropy_loss: 0.8965, loss: 0.8965
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>] 1130/1130, 869.0 task/s, elapsed: 1s, ETA:     0s
# 2022-03-19 18:21:30,846 - drugood - INFO - The previous best checkpoint /apdcephfs/private_yataobian/dl-research/graph-ood-benchmark/demo/work_dirs/lbap_core_ec50_assay_custom/best_ood_val:accuracy_epoch_2.pth was removed
# 2022-03-19 18:21:30,870 - drugood - INFO - Now best checkpoint is saved as best_ood_val:accuracy_epoch_3.pth.
# 2022-03-19 18:21:30,870 - drugood - INFO - Best ood_val:accuracy is 83.2743 at 3 epoch.
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 730/730, 582.1 task/s, elapsed: 1s, ETA:     0s[                                                  ] 0/1113, elapsed: 0s, ETA:[                                                  ] 0/730, elapsed: 0s, ETA:
# 2022-03-19 18:21:35,398 - drugood - INFO - Epoch(val) [3][6]	ood_val:accuracy: 83.2743, ood_val:auc: 60.7622, iid_val:accuracy: 67.9699, iid_val:auc: 66.3614, ood_test:accuracy: 75.7412, ood_test:auc: 65.9827, iid_test:accuracy: 68.4932, iid_test:auc: 65.7511
# 2022-03-19 18:21:38,556 - drugood - INFO - Epoch [4][5/16]	lr: 1.000e-04, eta: 0:00:08, time: 0.625, data_time: 0.576, memory: 264, crossentropy_loss: 0.8604, loss: 0.8604
# 2022-03-19 18:21:38,942 - drugood - INFO - Epoch [4][10/16]	lr: 1.000e-04, eta: 0:00:06, time: 0.079, data_time: 0.042, memory: 264, crossentropy_loss: 0.7079, loss: 0.7079
# 2022-03-19 18:21:39,264 - drugood - INFO - Epoch [4][15/16]	lr: 1.000e-04, eta: 0:00:04, time: 0.064, data_time: 0.031, memory: 264, crossentropy_loss: 0.7459, loss: 0.7459
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>] 1130/1130, 813.4 task/s, elapsed: 1s, ETA:     0s
# 2022-03-19 18:21:40,811 - drugood - INFO - The previous best checkpoint /apdcephfs/private_yataobian/dl-research/graph-ood-benchmark/demo/work_dirs/lbap_core_ec50_assay_custom/best_ood_val:accuracy_epoch_3.pth was removed
# 2022-03-19 18:21:40,836 - drugood - INFO - Now best checkpoint is saved as best_ood_val:accuracy_epoch_4.pth.
# 2022-03-19 18:21:40,836 - drugood - INFO - Best ood_val:accuracy is 86.9912 at 4 epoch.
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 730/730, 502.2 task/s, elapsed: 1s, ETA:     0s[                                                  ] 0/1113, elapsed: 0s, ETA:[                                                  ] 0/730, elapsed: 0s, ETA:
# 2022-03-19 18:21:45,245 - drugood - INFO - Epoch(val) [4][6]	ood_val:accuracy: 86.9912, ood_val:auc: 63.1814, iid_val:accuracy: 87.6692, iid_val:auc: 78.2343, ood_test:accuracy: 84.3666, ood_test:auc: 64.0107, iid_test:accuracy: 88.4932, iid_test:auc: 84.2833
# 2022-03-19 18:21:48,912 - drugood - INFO - Epoch [5][5/16]	lr: 1.000e-04, eta: 0:00:03, time: 0.729, data_time: 0.686, memory: 264, crossentropy_loss: 0.6584, loss: 0.6584
# 2022-03-19 18:21:49,241 - drugood - INFO - Epoch [5][10/16]	lr: 1.000e-04, eta: 0:00:01, time: 0.065, data_time: 0.028, memory: 264, crossentropy_loss: 0.6552, loss: 0.6552
# 2022-03-19 18:21:49,604 - drugood - INFO - Epoch [5][15/16]	lr: 1.000e-04, eta: 0:00:00, time: 0.074, data_time: 0.036, memory: 264, crossentropy_loss: 0.6526, loss: 0.6526
# 2022-03-19 18:21:49,696 - drugood - INFO - Saving checkpoint at 5 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 730/730, 507.8 task/s, elapsed: 1s, ETA:     0s[                                                  ] 0/665, elapsed: 0s, ETA:[                                                  ] 0/1113, elapsed: 0s, ETA:[                                                  ] 0/730, elapsed: 0s, ETA:
# 2022-03-19 18:21:55,655 - drugood - INFO - Epoch(val) [5][6]	ood_val:accuracy: 59.2920, ood_val:auc: 60.0340, iid_val:accuracy: 81.8045, iid_val:auc: 77.0354, ood_test:accuracy: 68.3738, ood_test:auc: 65.4762, iid_test:accuracy: 84.7945, iid_test:auc: 86.6539
